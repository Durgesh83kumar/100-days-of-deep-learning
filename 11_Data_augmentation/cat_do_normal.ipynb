# %%
import cv2
import os
import random
import numpy as np

# %%
mydir = r'D:\deep_learning\11_Data_augmentation\Cat vs Dog\train'

# %%
categories = ['Cat','Dog']

# %%
data=[]
for i in categories:
    folder_path = os.path.join(mydir,i)

    if i=='cats':
        label = 0
    else:
        label = 1

    for j in os.listdir(folder_path):
        img_path = os.path.join(folder_path,j)
        img = cv2.imread(img_path)
        img = cv2.resize(img,(150,150))
        data.append([img,label])

# %%
random.shuffle(data)

# %%
X = []
y = []
for i in data:
    X.append(i[0])
    y.append(i[1])

# %%
y = np.array(y)

# %%
X = np.array(X)

# %%
X.shape
# Out:
# (2199, 150, 150, 3)

# %%
X = X/255

# %%
# Create CNN from here

from keras import Sequential
from keras.layers import Conv2D,MaxPooling2D,Dense,Flatten,Activation,Dropout

# %%
model = Sequential()
model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
# model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32,kernel_size=(3,3),activation='relu'))
# model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
# model.add(Activation('relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten()) # this converts our 3D feature maps to 1D feature vectors
model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))

model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
# Out:
# d:\deep_learning\11_Data_augmentation\data_aug_venv\lib\site-packages\keras\src\layers\convolutional\base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
history = model.fit(X,y,epochs=5,validation_split=0.1)
# Out:
# Epoch 1/5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 8s 108ms/step - accuracy: 0.9929 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 8.1588e-08
# Epoch 2/5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 107ms/step - accuracy: 1.0000 - loss: 3.4193e-06 - val_accuracy: 1.0000 - val_loss: 1.7054e-08
# Epoch 3/5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 106ms/step - accuracy: 1.0000 - loss: 4.7216e-06 - val_accuracy: 1.0000 - val_loss: 2.6228e-09
# Epoch 4/5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 115ms/step - accuracy: 1.0000 - loss: 2.2698e-06 - val_accuracy: 1.0000 - val_loss: 8.2111e-10
# Epoch 5/5
# 62/62 ━━━━━━━━━━━━━━━━━━━━ 7s 110ms/step - accuracy: 1.0000 - loss: 8.3298e-06 - val_accuracy: 1.0000 - val_loss: 5.7873e-11

# %% [markdown]
# ## Data Augmentation

# %%
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
batch_size = 16

train_datagen = ImageDataGenerator(
    rescale=1./255,
    shear_range = 0.2,
    zoom_range = 0.2,
    horizontal_flip =True,
)


test_datagen = ImageDataGenerator(rescale=1./255)


train_generator = train_datagen.flow_from_directory(
    'Cat vs Dog/train',
    target_size = (150,150),
    batch_size = batch_size,
    class_mode = 'binary'
)


validation_generator = test_datagen.flow_from_directory(
    'Cat vs Dog/validation',
    target_size = (150,150),
    batch_size = batch_size,
    class_mode='binary'
)
# Out:
# Found 2199 images belonging to 2 classes.
# Found 200 images belonging to 2 classes.

# %%
model = Sequential()

model.add(Conv2D(32,kernel_size=(3,3),activation='relu',input_shape=(150,150,3)))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(32,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64,kernel_size=(3,3),activation='relu'))
model.add(MaxPooling2D(pool_size=(2,2)))


model.add(Flatten())

model.add(Dense(64,activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1,activation='sigmoid'))


model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])

# %%
model.fit(
    train_generator,
    steps_per_epoch=2000 // batch_size,
    epochs=25,
    validation_data=validation_generator,
    validation_steps=800 // batch_size
)
# Out:
# Epoch 1/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 17s 127ms/step - accuracy: 0.4997 - loss: 0.7011 - val_accuracy: 0.5700 - val_loss: 0.6929
# Epoch 2/25
#   2/125 ━━━━━━━━━━━━━━━━━━━━ 7s 58ms/step - accuracy: 0.6875 - loss: 0.6919
# d:\deep_learning\11_Data_augmentation\data_aug_venv\lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.5288 - loss: 0.6925 - val_accuracy: 0.5000 - val_loss: 0.6936
# Epoch 3/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 16s 131ms/step - accuracy: 0.4982 - loss: 0.6949 - val_accuracy: 0.5000 - val_loss: 0.6927
# Epoch 4/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.4856 - loss: 0.6943 - val_accuracy: 0.5350 - val_loss: 0.6928
# Epoch 5/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 18s 142ms/step - accuracy: 0.5003 - loss: 0.6939 - val_accuracy: 0.5200 - val_loss: 0.6925
# Epoch 6/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.5288 - loss: 0.6920 - val_accuracy: 0.5250 - val_loss: 0.6927
# Epoch 7/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 105ms/step - accuracy: 0.5013 - loss: 0.6933 - val_accuracy: 0.5050 - val_loss: 0.7072
# Epoch 8/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.5096 - loss: 0.6897 - val_accuracy: 0.5250 - val_loss: 0.6936
# Epoch 9/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 12s 96ms/step - accuracy: 0.5334 - loss: 0.6921 - val_accuracy: 0.5050 - val_loss: 0.6903
# Epoch 10/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.4856 - loss: 0.6945 - val_accuracy: 0.5500 - val_loss: 0.6891
# Epoch 11/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 107ms/step - accuracy: 0.5460 - loss: 0.6875 - val_accuracy: 0.5450 - val_loss: 0.6879
# Epoch 12/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6058 - loss: 0.6798 - val_accuracy: 0.5200 - val_loss: 0.6911
# Epoch 13/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.5560 - loss: 0.6850 - val_accuracy: 0.5500 - val_loss: 0.6870
# Epoch 14/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5529 - loss: 0.6878 - val_accuracy: 0.5250 - val_loss: 0.6877
# Epoch 15/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 102ms/step - accuracy: 0.5776 - loss: 0.6806 - val_accuracy: 0.5650 - val_loss: 0.6935
# Epoch 16/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5385 - loss: 0.6922 - val_accuracy: 0.5300 - val_loss: 0.6842
# Epoch 17/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 100ms/step - accuracy: 0.5952 - loss: 0.6763 - val_accuracy: 0.5500 - val_loss: 0.6752
# Epoch 18/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6635 - loss: 0.6455 - val_accuracy: 0.5700 - val_loss: 0.6724
# Epoch 19/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - accuracy: 0.6208 - loss: 0.6676 - val_accuracy: 0.5700 - val_loss: 0.6799
# Epoch 20/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.6442 - loss: 0.6728 - val_accuracy: 0.5650 - val_loss: 0.7020
# Epoch 21/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 104ms/step - accuracy: 0.5856 - loss: 0.6702 - val_accuracy: 0.5750 - val_loss: 0.6750
# Epoch 22/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.5817 - loss: 0.6649 - val_accuracy: 0.5950 - val_loss: 0.6686
# Epoch 23/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 103ms/step - accuracy: 0.6223 - loss: 0.6588 - val_accuracy: 0.5850 - val_loss: 0.6646
# Epoch 24/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6106 - loss: 0.6654 - val_accuracy: 0.6100 - val_loss: 0.6693
# Epoch 25/25
# 125/125 ━━━━━━━━━━━━━━━━━━━━ 13s 101ms/step - accuracy: 0.6087 - loss: 0.6611 - val_accuracy: 0.5900 - val_loss: 0.6806

# %%
model.save("cat_dog_model.keras")

# %%
from keras.models import load_model
model = load_model("cat_dog_model.keras")

# %%
model
# Out:
# <Sequential name=sequential_5, built=True>
