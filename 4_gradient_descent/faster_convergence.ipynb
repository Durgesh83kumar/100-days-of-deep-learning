# %% [markdown]
# ### Which is the faster to converge (given same # epochs)?
# - if we are training model for equal no. of epochs then
#
# - Stochastic gradient descent will converge towards solution (i.e. konsa algorithm pehle best weights and bias ke values find karega),faster than Batch_GD

# %%
import numpy as np
import pandas as pd
import time

# %%
df = pd.read_csv('D:\machine_learning\decision_trees\Social_Network_Ads.csv')
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# <>:1: SyntaxWarning: invalid escape sequence '\m'
# C:\Users\Durgesh Kumar\AppData\Local\Temp\ipykernel_23856\3441723679.py:1: SyntaxWarning: invalid escape sequence '\m'
#   df = pd.read_csv('D:\machine_learning\decision_trees\Social_Network_Ads.csv')

# %%
df = df[['Age', 'EstimatedSalary', 'Purchased']]

# %%
X = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

X_scaled = scaler.fit_transform(X)

# %%
X_scaled.shape
# Out:
# (400, 2)

# %%
import tensorflow as tf
from tensorflow import keras
from keras import Sequential
from keras.layers import Dense

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential_4"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_12 (Dense)                │ (None, 10)             │            30 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_13 (Dense)                │ (None, 10)             │           110 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_14 (Dense)                │ (None, 1)              │            11 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 151 (604.00 B)
#  Trainable params: 151 (604.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_scaled,y,epochs=10,batch_size=1,validation_split=0.2)
# Out:
# Epoch 1/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8062 - loss: 0.4864 - val_accuracy: 0.5500 - val_loss: 0.6815
# Epoch 2/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8375 - loss: 0.3589 - val_accuracy: 0.6125 - val_loss: 0.5960
# Epoch 3/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8594 - loss: 0.3174 - val_accuracy: 0.6500 - val_loss: 0.5304
# Epoch 4/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8656 - loss: 0.3020 - val_accuracy: 0.7625 - val_loss: 0.4879
# Epoch 5/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8750 - loss: 0.2998 - val_accuracy: 0.8125 - val_loss: 0.4443
# Epoch 6/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8625 - loss: 0.2939 - val_accuracy: 0.8125 - val_loss: 0.4000
# Epoch 7/10
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8625 - loss: 0.2943 - val_accuracy: 0.8875 - val_loss: 0.3673
# Epoch 8/10
# ...

# %% [markdown]
# ### Another difference
#
# - reduce of loss function in SGD is very unstable
#
# - reduce of loss function in batch_GD is very stable

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])

history = model.fit(X_scaled,y,epochs=500,batch_size=1,validation_split=0.2)
# Out:
# Epoch 1/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.8094 - loss: 0.6174 - val_accuracy: 0.6125 - val_loss: 0.6855
# Epoch 2/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8438 - loss: 0.4777 - val_accuracy: 0.6500 - val_loss: 0.6271
# Epoch 3/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8406 - loss: 0.3670 - val_accuracy: 0.6875 - val_loss: 0.5375
# Epoch 4/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8469 - loss: 0.3187 - val_accuracy: 0.7000 - val_loss: 0.4715
# Epoch 5/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step - accuracy: 0.8469 - loss: 0.2963 - val_accuracy: 0.7375 - val_loss: 0.4020
# Epoch 6/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8625 - loss: 0.2891 - val_accuracy: 0.8000 - val_loss: 0.3533
# Epoch 7/500
# 320/320 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8656 - loss: 0.2827 - val_accuracy: 0.8750 - val_loss: 0.3135
# Epoch 8/500
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])

# %%
model = Sequential()

model.add(Dense(10,activation='relu',input_dim=2))
model.add(Dense(10,activation='relu'))
model.add(Dense(1,activation='sigmoid'))
# Out:
# d:\anaconda3\envs\ml_1env\Lib\site-packages\keras\src\layers\core\dense.py:106: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'])
#start = time.time()
history = model.fit(X_scaled,y,epochs=500,batch_size=400,validation_split=0.2)
# Out:
# Epoch 1/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 822ms/step - accuracy: 0.3125 - loss: 0.7652 - val_accuracy: 0.7250 - val_loss: 0.5956
# Epoch 2/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3219 - loss: 0.7533 - val_accuracy: 0.7500 - val_loss: 0.5942
# Epoch 3/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step - accuracy: 0.3219 - loss: 0.7452 - val_accuracy: 0.7625 - val_loss: 0.5930
# Epoch 4/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step - accuracy: 0.3313 - loss: 0.7386 - val_accuracy: 0.7750 - val_loss: 0.5917
# Epoch 5/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.3469 - loss: 0.7329 - val_accuracy: 0.7750 - val_loss: 0.5906
# Epoch 6/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 79ms/step - accuracy: 0.3625 - loss: 0.7279 - val_accuracy: 0.7750 - val_loss: 0.5895
# Epoch 7/500
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 76ms/step - accuracy: 0.3750 - loss: 0.7233 - val_accuracy: 0.7750 - val_loss: 0.5883
# Epoch 8/500
# ...

# %%
plt.plot(history.history['loss'])
